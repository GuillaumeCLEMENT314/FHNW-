# %% [markdown]
# # Quantum Bloch equation

# %% [markdown]
# ## Definition of the physical system

# %% [markdown]
# We are here solving the quantum Bloch equation for $^{87}\text{Rb}$  in order to get a more precise estimation of our needs in pump field (optical and RF) in order to successfully build the self-oscillating OPM.
# The expression we will be using comes directly from the paper "Rubidium 87 D Line Data" by Daniel A. Steck.
#
# Here is the general expression:
#
# \begin{align*}
# \frac{\partial}{\partial t} \tilde{\rho}_{\alpha\, m_\alpha,\, \beta\, m_\beta}
# &= -\frac{i}{2} \bigg[
#     \delta_{\alpha e} \sum_{m_g} \Omega(m_\alpha, m_g)\, \tilde{\rho}_{g\, m_g,\, \beta\, m_\beta}
#     - \delta_{g \beta} \sum_{m_e} \Omega(m_e, m_\beta)\, \tilde{\rho}_{\alpha\, m_\alpha,\, e\, m_e} \\
# &\quad
#     + \delta_{\alpha g} \sum_{m_e} \Omega^*(m_e, m_\alpha)\, \tilde{\rho}_{e\, m_e,\, \beta\, m_\beta}
#     - \delta_{e \beta} \sum_{m_g} \Omega^*(m_\beta, m_g)\, \tilde{\rho}_{\alpha\, m_\alpha,\, g\, m_g}
# \bigg] \\
# &\quad
#     - \delta_{\alpha e} \delta_{e \beta} \, \Gamma\, \tilde{\rho}_{\alpha\, m_\alpha,\, \beta\, m_\beta} \\
# &\quad
#     - \delta_{\alpha e} \delta_{g \beta} \, \frac{\Gamma}{2}\, \tilde{\rho}_{\alpha\, m_\alpha,\, \beta\, m_\beta} \\
# &\quad
#     - \delta_{\alpha g} \delta_{e \beta} \, \frac{\Gamma}{2}\, \tilde{\rho}_{\alpha\, m_\alpha,\, \beta\, m_\beta} \\
# &\quad
#     + \delta_{\alpha g} \delta_{g \beta} \, \Gamma \sum_{q=-1}^{1}
#     \tilde{\rho}_{e\,(m_\alpha+q),\, e\,(m_\beta+q)}\,
#     \langle F_e\, (m_\alpha+q) | F_g\, 1\, m_\alpha\, q \rangle\,
#     \langle F_e\, (m_\beta+q) | F_g\, 1\, m_\beta\, q \rangle \\
# &\quad
#     + i\, (\delta_{\alpha e} \delta_{g \beta} - \delta_{\alpha g} \delta_{e \beta})\, \Delta\,
#     \tilde{\rho}_{\alpha\, m_\alpha,\, \beta\, m_\beta}
# \end{align*}
#
# where
# \begin{align*}
# \Omega(m_e, m_g)
# &= \langle F_g \, m_g | F_e \, 1 \, m_e - (m_e - m_g) \rangle\, \Omega_{-(m_e - m_g)} \\
# &= (-1)^{F_e - F_g + m_e - m_g} \sqrt{\frac{2F_g + 1}{2F_e + 1}}\, \langle F_e \, m_e | F_g \, 1 \, m_g \, (m_e - m_g) \rangle\, \Omega_{-(m_e - m_g)}
# \end{align*}
#
# is the Rabi frequency between two magnetic sublevels, and
# \begin{align*}
# \Omega_q = \frac{2 \langle F_e || er || F_g \rangle E_q^{(+)}}{\hbar}
# \end{align*}
#
# It is important to precise that the indices  $\alpha, m_{\alpha}, \beta, m_{\beta}$ represent respectively our initial state and our final state for the transition of interest.

# %% [markdown]
# We can break down this equation into three categories. <br>
# **Pumping** :
# \begin{align*}
# P&= -\frac{i}{2} \bigg[
#     \delta_{\alpha e} \sum_{m_g} \Omega(m_\alpha, m_g)\, \tilde{\rho}_{g\, m_g,\, \beta\, m_\beta}
#     - \delta_{g \beta} \sum_{m_e} \Omega(m_e, m_\beta)\, \tilde{\rho}_{\alpha\, m_\alpha,\, e\, m_e} \\
# &\quad
#     + \delta_{\alpha g} \sum_{m_e} \Omega^*(m_e, m_\alpha)\, \tilde{\rho}_{e\, m_e,\, \beta\, m_\beta}
#     - \delta_{e \beta} \sum_{m_g} \Omega^*(m_\beta, m_g)\, \tilde{\rho}_{\alpha\, m_\alpha,\, g\, m_g}
# \bigg] \quad
# \\
# \end{align*}
#
# **Dissipation** :
# \begin{align*}
# D = & - \delta_{\alpha e} \delta_{e \beta} \, \Gamma\, \tilde{\rho}_{\alpha\, m_\alpha,\, \beta\, m_\beta} \\
# \quad
#     &- \delta_{\alpha e} \delta_{g \beta} \, \frac{\Gamma}{2}\, \tilde{\rho}_{\alpha\, m_\alpha,\, \beta\, m_\beta} \\
# \quad
#     &- \delta_{\alpha g} \delta_{e \beta} \, \frac{\Gamma}{2}\, \tilde{\rho}_{\alpha\, m_\alpha,\, \beta\, m_\beta} \\
# \quad
#     &+ \delta_{\alpha g} \delta_{g \beta} \, \Gamma \sum_{q=-1}^{1}
#     \tilde{\rho}_{e\,(m_\alpha+q),\, e\,(m_\beta+q)}\,
#     \langle F_e\, (m_\alpha+q) | F_g\, 1\, m_\alpha\, q \rangle\,
#     \langle F_e\, (m_\beta+q) | F_g\, 1\, m_\beta\, q \rangle
# &\quad
# \end{align*}
#
# **Free Evolution** :
# \begin{align*}
# E = &\quad + i\, (\delta_{\alpha e} \delta_{g \beta} - \delta_{\alpha g} \delta_{e \beta})\, \Delta\,
#     \tilde{\rho}_{\alpha\, m_\alpha,\, \beta\, m_\beta}
#     \quad
# \end{align*}

# %% [markdown]
# The energy diagram of our system is the following:
#
# <img src=".\RbD1_even_smaller.png" width=1000px height=400px>
#
# We are now interested in multiple transitions. For each of them, we have to run the equatio (that will get largely simplified depending on the type of transition). We will describe separately the transitions for the magnetic sublevels transitions and the optical ones.

# %% [markdown]
# ### Magnetic sublevels
#
# We will start by making the equations for every transition in our magnetic sublevels at the ground state. We want to be able to jump from one to the upper or lower one. We thus have 8 possible transitions:
# \begin{alignat}{3}
#     &\ket{\alpha, \, m_{\alpha}} \quad &\rightarrow\quad & \ket{\beta, \, m_{\beta}} \nonumber \\
#     &\ket{F, \, m_F = -2} \quad &\rightarrow\quad & \ket{F, \, m_F = -1} \\
#     &\ket{F, \, m_F = -1} \quad &\rightarrow\quad & \ket{F, \, m_F = 0}  \\
#     &\ket{F, \, m_F = 0}  \quad &\rightarrow\quad & \ket{F, \, m_F = +1} \\
#     &\ket{F, \, m_F = +1} \quad &\rightarrow\quad & \ket{F, \, m_F = +2} \\
#     &\ket{F, \, m_F = +2} \quad &\rightarrow\quad & \ket{F, \, m_F = +1} \\
#     &\ket{F, \, m_F = +1} \quad &\rightarrow\quad & \ket{F, \, m_F = 0}  \\
#     &\ket{F, \, m_F = 0}  \quad &\rightarrow\quad & \ket{F, \, m_F = -1} \\
#     &\ket{F, \, m_F = -1} \quad &\rightarrow\quad & \ket{F, \, m_F = -2}
# \end{alignat}

# %% [markdown]
# Now we have the tedious task to compute the quantum bloch equation for every transition of interest. For the sake of simplicity, only the final result will be written here. The general form can be given, since the kronecker function is about ground and excited states, and here we only have ground states.

# %% [markdown]
# General form:
#
# \begin{align*}
#     \left. \partial_t \rho_{\alpha \, m_{\alpha}, \beta \, m_{\beta}} \right|_{\alpha=g, \beta=g}  = & - \frac{i}{2} \left[-\sum_{m_e} \Omega(m_e,m_{\beta}) \rho_{\alpha \, m_{\alpha}, e \, m_e} + \sum_{m_e} \Omega^*(m_e, m_{\alpha}) \rho_{e \, m_e, \beta \, m_{\beta}} \right] \\
#     &+ \Gamma \sum^1_{q=-1} \rho_{e(m_{\alpha}+q),e(m_{\beta}+q)} \langle{F' \, (m_{\alpha}+q)}|{F \, 1 \, m_{\alpha} \, q}\rangle \langle{F'\, (m_{\beta}+q)}| {F \, 1 \, m_{\beta} \, q}\rangle
# \end{align*}

# %% [markdown]
# (1):
#
# \begin{align*}
#     \partial_t \rho_{g \, -2, g \, -1} = & - \frac{i}{2} \left[-\sum_{m_e} \Omega(m_e,-1) \rho_{g \, -2, e \, m_e} + \sum_{m_e} \Omega^*(m_e, -2) \rho_{e \, m_e, g \, -1} \right] \\
#     &+ \Gamma \sum^1_{q=-1} \rho_{e(-2+q),e(-1+q)} \langle{F' \, (-2+q)}|{F \, 1 \, -2 \, q}\rangle \langle{F'\, (-1+q)}| {F \, 1 \, -1 \, q}\rangle
# \end{align*}

# %% [markdown]
# (2):
#
# \begin{align*}
#     \partial_t \rho_{g \, -1, g \, 0} = & - \frac{i}{2} \left[-\sum_{m_e} \Omega(m_e,0) \rho_{g \, -1, e \, m_e} + \sum_{m_e} \Omega^*(m_e, -1) \rho_{e \, m_e, g \, 0} \right] \\
#     &+ \Gamma \sum^1_{q=-1} \rho_{e(-1+q),e(0+q)} \langle{F' \, (-1+q)}|{F \, 1 \, -1 \, q}\rangle \langle{F'\, (0+q)}| {F \, 1 \, 0 \, q}\rangle
# \end{align*}

# %% [markdown]
# (3):
#
# \begin{align*}
#     \partial_t \rho_{g \, 0, g \, +1} = & - \frac{i}{2} \left[-\sum_{m_e} \Omega(m_e,+1) \rho_{g \, 0, e \, m_e} + \sum_{m_e} \Omega^*(m_e, 0) \rho_{e \, m_e, g \, +1} \right] \\
#     &+ \Gamma \sum^1_{q=-1} \rho_{e(0+q),e(+1+q)} \langle{F' \, (0+q)}|{F \, 1 \, 0 \, q}\rangle \langle{F'\, (+1+q)}| {F \, 1 \, +1 \, q}\rangle
# \end{align*}

# %% [markdown]
# (4):
#
# \begin{align*}
#     \partial_t \rho_{g \, +1, g \, +2} = & - \frac{i}{2} \left[-\sum_{m_e} \Omega(m_e,+2) \rho_{g \, +1, e \, m_e} + \sum_{m_e} \Omega^*(m_e, +1) \rho_{e \, m_e, g \, +2} \right] \\
#     &+ \Gamma \sum^1_{q=-1} \rho_{e(+1+q),e(+2+q)} \langle{F' \, (+1+q)}|{F \, 1 \, +1 \, q}\rangle \langle{F'\, (+2+q)}| {F \, 1 \, +2 \, q}\rangle
# \end{align*}

# %% [markdown]
# (5):
#
# \begin{align*}
#     \partial_t \rho_{g \, +2, g \, +1} = & - \frac{i}{2} \left[-\sum_{m_e} \Omega(m_e,+1) \rho_{g \, +2, e \, m_e} + \sum_{m_e} \Omega^*(m_e, +2) \rho_{e \, m_e, g \, +1} \right] \\
#     &+ \Gamma \sum^1_{q=-1} \rho_{e(+2+q),e(+1+q)} \langle{F' \, (+2+q)}|{F \, 1 \, +2 \, q}\rangle \langle{F'\, (+1+q)}| {F \, 1 \, +1 \, q}\rangle
# \end{align*}

# %% [markdown]
# (6):
#
# \begin{align*}
#     \partial_t \rho_{g \, +1, g \, 0} = & - \frac{i}{2} \left[-\sum_{m_e} \Omega(m_e,0) \rho_{g \, +1, e \, m_e} + \sum_{m_e} \Omega^*(m_e, +1) \rho_{e \, m_e, g \, 0} \right] \\
#     &+ \Gamma \sum^1_{q=-1} \rho_{e(+1+q),e(0+q)} \langle{F' \, (+1+q)}|{F \, 1 \, +1 \, q}\rangle \langle{F'\, (0+q)}| {F \, 1 \, 0 \, q}\rangle
# \end{align*}

# %% [markdown]
# (7):
#
# \begin{align*}
#     \partial_t \rho_{g \, 0, g \, -1} = & - \frac{i}{2} \left[-\sum_{m_e} \Omega(m_e,-1) \rho_{g \, 0, e \, m_e} + \sum_{m_e} \Omega^*(m_e, 0) \rho_{e \, m_e, g \, -1} \right] \\
#     &+ \Gamma \sum^1_{q=-1} \rho_{e(0+q),e(-1+q)} \langle{F' \, (0+q)}|{F \, 1 \, 0 \, q}\rangle \langle{F'\, (-1+q)}| {F \, 1 \, -1 \, q}\rangle
# \end{align*}

# %% [markdown]
# (8):
#
# \begin{align*}
#     \partial_t \rho_{g \, -1, g \, -2} = & - \frac{i}{2} \left[-\sum_{m_e} \Omega(m_e,-2) \rho_{g \, -1, e \, m_e} + \sum_{m_e} \Omega^*(m_e, -1) \rho_{e \, m_e, g \, -2} \right] \\
#     &+ \Gamma \sum^1_{q=-1} \rho_{e(-1+q),e(-2+q)} \langle{F' \, (-1+q)}|{F \, 1 \, -1 \, q}\rangle \langle{F'\, (-2+q)}| {F \, 1 \, -2 \, q}\rangle
# \end{align*}

# %% [markdown]
# ### Orbital excitations

# %% [markdown]
# We now take care of the optical pumping from a given magnetic sublevel to an excited one. Since we use positively circularly polarized light $\sigma^+$, we will only allow the transition from $m_F=x \rightarrow m_{F'}=x+1$.

# %% [markdown]
# We are thus interested in the following transitions:
#
# \begin{alignat}{3}
#     &\ket{\alpha, \, m_{\alpha}} \quad &\rightarrow\quad & \ket{\beta, \, m_{\beta}} \nonumber \\
#     &\ket{F, \, m_F = -2} \quad &\rightarrow\quad & \ket{F', \, m_{F'} = -1} \tag{1'} \\
#     &\ket{F, \, m_F = -1} \quad &\rightarrow\quad & \ket{F', \, m_{F'} = 0}  \tag{2'} \\
#     &\ket{F, \, m_F = 0}  \quad &\rightarrow\quad & \ket{F', \, m_{F'} = +1} \tag{3'}
# \end{alignat}

# %% [markdown]
# We now have the general form for these transitions:
#
# \begin{align*}
#     \left. \partial_t  \rho_{\alpha \, m_{\alpha}, \beta \, m_{\beta}} \right|_{\alpha=g, \beta=e} = & -\frac{i}{2} \left[ \sum_{m_e} \Omega^*(m_e, m_{\alpha}) \rho_{e \, m_e, \beta \, m_{\beta}} - \sum_{m_g}\Omega^*(m_{\beta},m_g)\rho_{\alpha \, m_{\alpha}, g \, m_g} \right] \\
#     & - \frac{\Gamma}{2} \rho_{\alpha \, m_{\alpha}, \beta \, m_{\beta}}\\
#     & -i \Delta \rho_{\alpha \, m_{\alpha}, \beta \, m_{\beta}}
# \end{align*}

# %% [markdown]
# (1'):
#
# \begin{align*}
#     \partial_t  \rho_{g \, -2, e \, -1} = & -\frac{i}{2} \left[ \sum_{m_e} \Omega^*(m_e, -2) \rho_{e \, m_e, e \, -1} - \sum_{m_g}\Omega^*(-1,m_g)\rho_{g \, -2, g \, m_g} \right] \\
#     & - \frac{\Gamma}{2} \rho_{g \, -2, e \, -1}\\
#     & -i \Delta \rho_{g \, -2, e \, -1}
# \end{align*}

# %% [markdown]
# (2'):
#
# \begin{align*}
#     \partial_t  \rho_{g \, -1, e \, 0}  = & -\frac{i}{2} \left[ \sum_{m_e} \Omega^*(m_e, -1) \rho_{e \, m_e, e \, 0} - \sum_{m_g}\Omega^*(0,m_g)\rho_{g \, -1, g \, m_g} \right] \\
#     & - \frac{\Gamma}{2} \rho_{g \, -1, e \, 0}\\
#     & -i \Delta \rho_{g \, -1, e \, 0}
# \end{align*}

# %% [markdown]
# (3'):
#
# \begin{align*}
#     \partial_t  \rho_{g \, 0, e \, -1}  = & -\frac{i}{2} \left[ \sum_{m_e} \Omega^*(m_e, 0) \rho_{e \, m_e, e \, -1} - \sum_{m_g}\Omega^*(-1,m_g)\rho_{g \, 0, g \, m_g} \right] \\
#     & - \frac{\Gamma}{2} \rho_{g \, 0, e \, -1}\\
#     & -i \Delta \rho_{g \, 0, e \, -1}
# \end{align*}

# %% [markdown]
# ## Computation

# %% [markdown]
# We now have to compute all these parts. We will here explicit the expressions in order to understand the math given in the useful functions.
#
# - Clebsch-Gordan Coefficients:
# $$\langle F \, M | j_1 \, J_2 \, m_1 \, m_2 \rangle \equiv \langle j_1 \, J_2 \, m_1 \, m_2 |  F \, M \rangle$$
# $$ \langle F \, M | j_1 \, J_2 \, m_1 \, m_2 \rangle = (-1)^{-j_1+j_2+M} \sqrt{2J+1} \begin{pmatrix} j_1 & j_2 & J \\ m_1 & m_2 & M \end{pmatrix}$$
#
# - Overall Rabi frequency with polarization q :
# $$\Omega_q = \frac{2\langle F_e || er ||| F_g \rangle E_q^{(+)}}{\hbar}$$
# $$\Omega_q = \frac{2}{\hbar}E_q^{(+)} (-1)^{F_e+J_g+1+I}\sqrt{(2F_e+1)(2F_g+1)}\begin{pmatrix} J_e & F_e & I \\ F_g & J_g & 1 \end{pmatrix} \langle J_e||er||J_g\rangle$$
# with $\langle J_e||er||J_g\rangle$ a transition constant

# %% [markdown]
# ### Useful functions:

# %%
import numpy as np
from sympy import S
from sympy.physics.quantum.cg import CG
from scipy.constants import *
from sympy.physics.wigner import wigner_6j

### constants
dipole_J = 4.231e-29 #C.m ; <Je || er || Jg>

### functions
def hyperfine_reduced_matrix_element(Fe, Fg, Je, Jg, I, dipole_J):
    """Compute <Fe || er || Fg> from <Je || er || Jg>"""
    phase = (-1)**(Fe + Jg + 1 + I)
    coeff = np.sqrt((2*Fe + 1)*(2*Fg + 1))
    sixj = wigner_6j(Je, Fe, I, Fg, Jg, 1)
    return float(phase * coeff * sixj * dipole_J)

def clebsch_gordan_coeff(F_coupled, m_coupled, F_elec, m_elec, F_photon, m_photon):
    J_ = S(F_coupled)
    M_ = S(m_coupled)
    j1_ = S(F_elec)
    j2_ = S(F_photon)
    m1_ = S(m_elec)
    m2_ = S(m_photon)
    cg = CG(j1_, m1_, j2_, m2_, J_, M_)
    value_cg = cg.doit()
    return value_cg

#this term appears only in optical pumping so it's ok to define the hyperfine reduced matrix element based on the constant for the D1 line
#ADD FIELD INTENSITY
def rabi_freq(J, M, j1, m1, m2, j2=1):
    cg = clebsch_gordan_coeff(J, M, j1, j2, m1, m2)
    prefactor = (-1)**(J-j1+M-m1) * np.sqrt((2*J+1)/(2*j1-1))
    hyperfine_red_mat_el = hyperfine_reduced_matrix_element(Fe=1, Fg=2, Je=1/2, Jg=1/2, I=3/2, dipole_J=dipole_J)
    rabi_frequency = prefactor * cg * hyperfine_red_mat_el
    return rabi_frequency

# %%
J = 1
M = 1
j1 = 1
m1 = 0
j2 = 1
m2 = 1
print(clebsch_gordan_coeff(J, M, j1, m1, m2, j2))
# Out:
# -sqrt(2)/2

# %%
print(rabi_freq(J,M,j1,m1,m2,j2))
# Out:
# 0

# %%
(-1)**(J-j1+M-m1) * np.sqrt((2*J+1)/(2*j1-1))
# Out:
# np.float64(-1.7320508075688772)

# %%
hyperfine_reduced_matrix_element(Fe=1, Fg=2, Je=1/2, Jg=1/2, I=3/2, dipole_J=dipole_J)
# Out:
# 4.730401806400805e-29

# %%
wigner_6j(1/2, 1, 3/2, 2, 1/2, 1)
# Out:
# sqrt(3)/6

# %%
1/3*2
# Out:
# 0.6666666666666666

# %%
1.5e-6/34e-9
# Out:
# 44.11764705882353

# %%
1023e-9/(44*109*40)
# Out:
# 5.33256880733945e-12

# %%
794.98 - 790.3
# Out:
# 4.680000000000064

# %%
4.68/0.055
# Out:
# 85.09090909090908

# %%
25+85
# Out:
# 110
